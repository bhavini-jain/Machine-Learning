# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder

# %%
pd.set_option('display.max_columns',None)

# %%
df=pd.read_csv(r'F:\Python_Class\Dataset\test.csv')
df
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0     1461          20       RH         80.0    11622   Pave   NaN      Reg
# 1     1462          20       RL         81.0    14267   Pave   NaN      IR1
# 2     1463          60       RL         74.0    13830   Pave   NaN      IR1
# 3     1464          60       RL         78.0     9978   Pave   NaN      IR1
# 4     1465         120       RL         43.0     5005   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1454  2915         160       RM         21.0     1936   Pave   NaN      Reg
# 1455  2916         160       RM         21.0     1894   Pave   NaN      Reg
# 1456  2917          20       RL        160.0    20000   Pave   NaN      Reg
# 1457  2918          85       RL         62.0    10441   Pave   NaN      Reg
# 1458  2919          60       RL         74.0     9627   Pave   NaN      Reg
#
# ...

# %%
df2=df[['KitchenQual','BldgType']]
df2
# Out:
#      KitchenQual BldgType
# 0             TA     1Fam
# 1             Gd     1Fam
# 2             TA     1Fam
# 3             Gd     1Fam
# 4             Gd   TwnhsE
# ...          ...      ...
# 1454          TA    Twnhs
# 1455          TA   TwnhsE
# 1456          TA     1Fam
# 1457          TA     1Fam
# 1458          TA     1Fam
#
# [1459 rows x 2 columns]

# %%
pd.set_option('display.max_rows',None)

# %%
df2['BldgType'].unique()
# Out:
# array(['1Fam', 'TwnhsE', 'Twnhs', 'Duplex', '2fmCon'], dtype=object)

# %%
le=LabelEncoder()

# %%
le.fit_transform(df2['BldgType'])
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
df2['BldgType_L_en']=le.fit_transform(df2['BldgType'])
# Out:
# C:\Users\Pankaj Chittora\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df2
# Out:
#      KitchenQual BldgType  BldgType_L_en
# 0             TA     1Fam              0
# 1             Gd     1Fam              0
# 2             TA     1Fam              0
# 3             Gd     1Fam              0
# 4             Gd   TwnhsE              4
# 5             TA     1Fam              0
# 6             TA     1Fam              0
# 7             TA     1Fam              0
# 8             Gd     1Fam              0
# 9             TA     1Fam              0
# 10            Gd   TwnhsE              4
# 11            TA    Twnhs              3
# 12            TA    Twnhs              3
# 13            Gd    Twnhs              3
# 14            TA    Twnhs              3
# 15            Ex     1Fam              0
# 16            Gd     1Fam              0
# 17            Ex     1Fam              0
# 18            Ex     1Fam              0
# 19            Ex     1Fam              0
# 20            Gd     1Fam              0
# 21            Gd   TwnhsE              4
# ...

# %%
df2['BldgType_L_en'].value_counts()
# Out:
# 0    1205
# 4     113
# 2      57
# 3      53
# 1      31
# Name: BldgType_L_en, dtype: int64

# %%
df2['BldgType'].value_counts()
# Out:
# 1Fam      1205
# TwnhsE     113
# Duplex      57
# Twnhs       53
# 2fmCon      31
# Name: BldgType, dtype: int64

# %%
df2['KitchenQual'].value_counts()
# Out:
# TA    757
# Gd    565
# Ex    105
# Fa     31
# Name: KitchenQual, dtype: int64

# %%
'''
TA-- 4
Gd-- 3
Ex-- 1
Fa-- 2
'''
'''
TA- Typlical/ AVerage
Gd -  Good
Ex-- Excellent
Fa-- Fair

'''
# Out:
# '\nTA- Typlical/ AVerage\nGd -  Good\nEx-- Excellent\nFa-- Fair\n\n'

# %%
order_label={'Ex':4,'Gd':3,'TA':2,'Fa':1}

# %%
df2['KitchenQual_onc_seq']=df2['KitchenQual'].map(order_label)
# Out:
# C:\Users\Pankaj Chittora\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df2
# Out:
#      KitchenQual BldgType  BldgType_L_en  KitchenQual_onc_seq
# 0             TA     1Fam              0                  2.0
# 1             Gd     1Fam              0                  3.0
# 2             TA     1Fam              0                  2.0
# 3             Gd     1Fam              0                  3.0
# 4             Gd   TwnhsE              4                  3.0
# 5             TA     1Fam              0                  2.0
# 6             TA     1Fam              0                  2.0
# 7             TA     1Fam              0                  2.0
# 8             Gd     1Fam              0                  3.0
# 9             TA     1Fam              0                  2.0
# 10            Gd   TwnhsE              4                  3.0
# 11            TA    Twnhs              3                  2.0
# 12            TA    Twnhs              3                  2.0
# 13            Gd    Twnhs              3                  3.0
# ...
